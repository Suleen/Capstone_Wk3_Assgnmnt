# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
# from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
# import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import sys
# !{sys.executable} -m pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/66/25/ff030e2437265616a1e9b25ccc864e0371a0bc3adb7c5a404fd661c6f4f6/beautifulsoup4-4.9.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 2.6MB/s eta 0:00:01
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.1 soupsieve-2.0.1

# %%
from bs4 import BeautifulSoup

# %%
import sys
# !{sys.executable} -m pip install lxml
# !{sys.executable} -m pip install html5lib
# !conda install lxml --yes
# !conda install html5lib --yes
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/79/37/d420b7fdc9a550bd29b8cfeacff3b38502d9600b09d7dfae9a69e623b891/lxml-4.5.2-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 6.0MB/s eta 0:00:01     |████████████████▏               | 2.8MB 6.0MB/s eta 0:00:01.0MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.2
# Requirement already satisfied: html5lib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.9999999)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from html5lib) (1.15.0)

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df_lst = pd.read_html(url)
type(df_lst)
print(len(df_lst))
# Out:
# list
# 3

# %%
df_lst1 = df_lst[0]
df_lst1[0:4]
len(df_lst1)
# df_lst1[1][1]
df_lst1_arr = np.array(df_lst1)
df_lst1_arr.shape
# df_lst1_arr[0][0]
# Out:
#   Postal Code       Borough     Neighbourhood
# 0         M1A  Not assigned      Not assigned
# 1         M2A  Not assigned      Not assigned
# 2         M3A    North York         Parkwoods
# 3         M4A    North York  Victoria Village
# 180
# (180, 3)

# %%
#Creating data frame from the array
neighborhoods=pd.DataFrame(df_lst1_arr)
# define the dataframe columns
column_names = ['PostalCode', 'Borough', 'Neighborhood']
neighborhoods.columns = column_names 
#Selecting only rows where borough name is assigned
neighborhoods=neighborhoods[neighborhoods['Borough'] != 'Not assigned']
neighborhoods.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Replacing any non assigned neighborhood to borough name
for i in range(0,neighborhoods.shape[0]):
        if neighborhoods.iloc[i,2] == 'Not assigned':
            neighborhoods.iloc[i,2] = neighborhoods.loc[i,0]

# %%
neighborhoods.shape
# Out:
# (103, 3)

# %%
import sys
# !{sys.executable} -m pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 8.6MB/s ta 0:00:011
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.15.0)
# Collecting future (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 10.4MB/s eta 0:00:01     |█████████████▉                  | 358kB 10.4MB/s eta 0:00:01
# Collecting click (from geocoder)
#   Using cached https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# Installing collected packages: ratelim, future, click, geocoder
# Successfully installed click-7.1.2 future-0.18.2 geocoder-1.38.1 ratelim-0.1.6

# %%
# import geocoder # import geocoder

# # initialize your variable to None
# lat_lng_coords = None

# # loop until you get the coordinates
# while(lat_lng_coords is None):
#   g = geocoder.google('{}, Toronto, Ontario'.format('M5A'))
#   lat_lng_coords = g.latlng

# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]

# %%
#Create data frame with the Geospatial_Coordinates file
df1 = pd.read_csv('/resources/labs/DP0701EN/Geospatial_Coordinates.csv')
df1.head()
df1.shape[0]
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 103

# %%
#Create columns for latitude and Longitude in neighborhood dataframe
neighborhoods['Latitude']= ""
neighborhoods['Longitude']= ""
neighborhoods.head()
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#   Latitude Longitude
# 2
# 3
# 4
# 5
# 6

# %%
#Populate Latitude Longitude in neighborhood with df1
for i in range(0,neighborhoods.shape[0]):
    for j in range(0, df1.shape[0]):
        if neighborhoods.iloc[i,0] == df1.iloc[j,0]:
            neighborhoods.iloc[i,3] = df1.iloc[j,1]
            neighborhoods.iloc[i,4] = df1.iloc[j,2]

# %%
neighborhoods.head()
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#   Latitude Longitude
# 2  43.7533  -79.3297
# 3  43.7259  -79.3156
# 4  43.6543  -79.3606
# 5  43.7185  -79.4648
# 6  43.6623  -79.3895

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %%
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1g-h516909a_0 --> 1.1.1g-h516909a_1
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-3.0           |   py36h45558ae_0         640 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.1.0               |   py36h831f99a_0        10.5 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-3.0-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.7.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.1.0-py36h831f99a_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.24.0-pyh9f0ad1d_0
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.10-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# pandas-1.1.0         | 10.5 MB   | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# cryptography-3.0     | 640 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="trnt_explorer")
location = geolocator.geocode(address)
print(location)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# Toronto, Golden Horseshoe, Ontario, M5H 2N2, Canada
# The geograpical coordinates of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

#Add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto) 
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'IJFLQV3IMIWD4YD52201FQZKKPXPVIS5P5M4K00ALNGY5TLE' # your Foursquare ID
CLIENT_SECRET = 'EMLUFXPWEFTPJU4KXN52RONCRSA4OX1SMIT3Q0O2TVB3X5IF' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IJFLQV3IMIWD4YD52201FQZKKPXPVIS5P5M4K00ALNGY5TLE
# CLIENT_SECRET:EMLUFXPWEFTPJU4KXN52RONCRSA4OX1SMIT3Q0O2TVB3X5IF

# %%
torontoDT_data = neighborhoods[neighborhoods['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
torontoDT_data.head(100)
torontoDT_data.shape
# Out:
#    PostalCode           Borough  \
# 0         M5A  Downtown Toronto
# 1         M7A  Downtown Toronto
# 2         M5B  Downtown Toronto
# 3         M5C  Downtown Toronto
# 4         M5E  Downtown Toronto
# 5         M5G  Downtown Toronto
# 6         M6G  Downtown Toronto
# 7         M5H  Downtown Toronto
# 8         M5J  Downtown Toronto
# 9         M5K  Downtown Toronto
# 10        M5L  Downtown Toronto
# 11        M5S  Downtown Toronto
# 12        M5T  Downtown Toronto
# 13        M5V  Downtown Toronto
# 14        M4W  Downtown Toronto
# 15        M5W  Downtown Toronto
# 16        M4X  Downtown Toronto
# 17        M5X  Downtown Toronto
# 18        M4Y  Downtown Toronto
#
#                                          Neighborhood Latitude Longitude
# 0                           Regent Park, Harbourfront  43.6543  -79.3606
# 1         Queen's Park, Ontario Provincial Government  43.6623  -79.3895
# 2                            Garden District, Ryerson  43.6572  -79.3789
# 3                                      St. James Town  43.6515  -79.3754
# 4                                         Berczy Park  43.6448  -79.3733
# 5                                  Central Bay Street   43.658  -79.3874
# 6                                            Christie  43.6695  -79.4226
# 7                            Richmond, Adelaide, King  43.6506  -79.3846
# 8   Harbourfront East, Union Station, Toronto Islands  43.6408  -79.3818
# 9            Toronto Dominion Centre, Design Exchange  43.6472  -79.3816
# 10                     Commerce Court, Victoria Hotel  43.6482  -79.3798
# 11                     University of Toronto, Harbord  43.6627     -79.4
# 12          Kensington Market, Chinatown, Grange Park  43.6532     -79.4
# 13  CN Tower, King and Spadina, Railway Lands, Har...  43.6289  -79.3944
# 14                                           Rosedale  43.6796  -79.3775
# 15                                     Stn A PO Boxes  43.6464  -79.3748
# 16                        St. James Town, Cabbagetown   43.668  -79.3677
# 17             First Canadian Place, Underground city  43.6484  -79.3823
# 18                               Church and Wellesley  43.6659  -79.3832
# (19, 5)

# %%
address = 'Downtown Toronto, ON, Canada'

geolocator = Nominatim(user_agent="TrntDT_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %%
# create map of DT Toronto using latitude and longitude values
map_DTtoronto = folium.Map(location=[latitude, longitude], zoom_start=10)

#Add markers to map
for lat, lng, borough, neighborhood in zip(torontoDT_data['Latitude'], torontoDT_data['Longitude'], torontoDT_data['Borough'], torontoDT_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_DTtoronto) 
    
map_DTtoronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT = 25):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
TorontoDT_venues = getNearbyVenues(names=torontoDT_data['Neighborhood'],
                                   latitudes=torontoDT_data['Latitude'],
                                   longitudes=torontoDT_data['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley

# %%
TorontoDT_venues.head()
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0           Tandem Coffee       43.653559       -79.361809
# 1        Roselle Desserts       43.653447       -79.362017
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0          Coffee Shop
# 1               Bakery
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
TorontoDT_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            25
# CN Tower, King and Spadina, Railway Lands, Harb...                     16
# Central Bay Street                                                     25
# Christie                                                               17
# Church and Wellesley                                                   25
# Commerce Court, Victoria Hotel                                         25
# First Canadian Place, Underground city                                 25
# Garden District, Ryerson                                               25
# Harbourfront East, Union Station, Toronto Islands                      25
# Kensington Market, Chinatown, Grange Park                              25
# Queen's Park, Ontario Provincial Government                            25
# Regent Park, Harbourfront                                              25
# Richmond, Adelaide, King                                               25
# Rosedale                                                                4
# St. James Town                                                         25
# St. James Town, Cabbagetown                                            25
# Stn A PO Boxes                                                         25
# Toronto Dominion Centre, Design Exchange                               25
# University of Toronto, Harbord                                         25
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             25
# CN Tower, King and Spadina, Railway Lands, Harb...                      16
# Central Bay Street                                                      25
# Christie                                                                17
# Church and Wellesley                                                    25
# Commerce Court, Victoria Hotel                                          25
# First Canadian Place, Underground city                                  25
# Garden District, Ryerson                                                25
# Harbourfront East, Union Station, Toronto Islands                       25
# Kensington Market, Chinatown, Grange Park                               25
# Queen's Park, Ontario Provincial Government                             25
# Regent Park, Harbourfront                                               25
# Richmond, Adelaide, King                                                25
# Rosedale                                                                 4
# St. James Town                                                          25
# St. James Town, Cabbagetown                                             25
# Stn A PO Boxes                                                          25
# Toronto Dominion Centre, Design Exchange                                25
# University of Toronto, Harbord                                          25
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            25              25
# CN Tower, King and Spadina, Railway Lands, Harb...     16              16
# Central Bay Street                                     25              25
# Christie                                               17              17
# Church and Wellesley                                   25              25
# Commerce Court, Victoria Hotel                         25              25
# First Canadian Place, Underground city                 25              25
# Garden District, Ryerson                               25              25
# Harbourfront East, Union Station, Toronto Islands      25              25
# Kensington Market, Chinatown, Grange Park              25              25
# Queen's Park, Ontario Provincial Government            25              25
# Regent Park, Harbourfront                              25              25
# Richmond, Adelaide, King                               25              25
# Rosedale                                                4               4
# St. James Town                                         25              25
# St. James Town, Cabbagetown                            25              25
# Stn A PO Boxes                                         25              25
# Toronto Dominion Centre, Design Exchange               25              25
# University of Toronto, Harbord                         25              25
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      25
# CN Tower, King and Spadina, Railway Lands, Harb...               16
# Central Bay Street                                               25
# Christie                                                         17
# Church and Wellesley                                             25
# Commerce Court, Victoria Hotel                                   25
# First Canadian Place, Underground city                           25
# Garden District, Ryerson                                         25
# Harbourfront East, Union Station, Toronto Islands                25
# Kensington Market, Chinatown, Grange Park                        25
# Queen's Park, Ontario Provincial Government                      25
# Regent Park, Harbourfront                                        25
# Richmond, Adelaide, King                                         25
# Rosedale                                                          4
# St. James Town                                                   25
# St. James Town, Cabbagetown                                      25
# Stn A PO Boxes                                                   25
# Toronto Dominion Centre, Design Exchange                         25
# University of Toronto, Harbord                                   25
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     25
# CN Tower, King and Spadina, Railway Lands, Harb...              16
# Central Bay Street                                              25
# Christie                                                        17
# Church and Wellesley                                            25
# Commerce Court, Victoria Hotel                                  25
# First Canadian Place, Underground city                          25
# Garden District, Ryerson                                        25
# Harbourfront East, Union Station, Toronto Islands               25
# Kensington Market, Chinatown, Grange Park                       25
# Queen's Park, Ontario Provincial Government                     25
# Regent Park, Harbourfront                                       25
# Richmond, Adelaide, King                                        25
# Rosedale                                                         4
# St. James Town                                                  25
# St. James Town, Cabbagetown                                     25
# Stn A PO Boxes                                                  25
# Toronto Dominion Centre, Design Exchange                        25
# University of Toronto, Harbord                                  25

# %%
print('There are {} uniques categories.'.format(len(TorontoDT_venues['Venue Category'].unique())))
# Out:
# There are 140 uniques categories.

# %%
TorontoDT_venues['Venue Category'].unique()
# Out:
# array(['Coffee Shop', 'Bakery', 'Distribution Center', 'Spa',
#        'Restaurant', 'Park', 'Pub', 'Breakfast Spot',
#        'Gym / Fitness Center', 'Historic Site', 'Farmers Market',
#        'Dessert Shop', 'Performing Arts Venue', 'Chocolate Shop',
#        'French Restaurant', 'Mexican Restaurant', 'Café', 'Creperie',
#        'Beer Bar', 'Arts & Crafts Store', 'Yoga Studio',
#        'Sushi Restaurant', 'Burrito Place', 'Japanese Restaurant',
#        'Hobby Shop', 'Diner', 'Theater', 'Fried Chicken Joint',
#        'Smoothie Shop', 'Bank', 'Sandwich Place', 'Clothing Store',
#        'Comic Shop', 'Pizza Place', 'Plaza', 'Music Venue',
#        'Burger Joint', 'Electronics Store', 'Sporting Goods Shop',
#        'Ramen Restaurant', 'Thai Restaurant', 'College Rec Center',
#        'Shopping Mall', 'Bookstore', 'Gastropub', 'Art Gallery',
#        'Italian Restaurant', 'Gym', 'Food Truck',
#        'Middle Eastern Restaurant', 'Cosmetics Shop', 'BBQ Joint',
#        'Poke Place', 'American Restaurant', 'Hotel',
#        'Vegetarian / Vegan Restaurant', 'Liquor Store', 'Concert Hall',
#        'Museum', 'Cocktail Bar', 'Seafood Restaurant', 'Fountain',
#        'Basketball Stadium', 'Bistro', 'Jazz Club', 'Fish Market',
#        'Tailor Shop', 'Modern European Restaurant', 'Bubble Tea Shop',
#        'Art Museum', 'Miscellaneous Shop', 'Bar', 'Grocery Store',
#        'Candy Store', 'Baby Store', 'Nightclub', 'Athletics & Sports',
#        'Asian Restaurant', 'Steakhouse', 'Speakeasy', 'Neighborhood',
#        'Food Court', 'Smoke Shop', 'General Travel',
#        'Monument / Landmark', 'Lounge', 'Salad Place', 'Deli / Bodega',
#        'Lake', 'Skating Rink', 'Supermarket', 'Ice Cream Shop',
#        'IT Services', 'New American Restaurant', 'Roof Deck',
#        'Dance Studio', 'Train Station', 'Gluten-free Restaurant',
#        'College Gym', 'Comfort Food Restaurant', 'Chinese Restaurant',
#        'College Arts Building', 'Video Game Store', 'Organic Grocery',
#        'Vietnamese Restaurant', 'Caribbean Restaurant', 'Cheese Shop',
#        'Belgian Restaurant', 'Gourmet Shop', 'Wine Bar', 'Gaming Cafe',
#        'Airport', 'Airport Lounge', 'Harbor / Marina',
#        'Airport Food Court', 'Airport Gate', 'Plane', 'Boutique',
#        'Airport Service', 'Rental Car Location', 'Airport Terminal',
#        'Sculpture Garden', 'Boat or Ferry', 'Playground', 'Trail',
#        'Indian Restaurant', 'Jewelry Store', 'General Entertainment',
#        'Butcher', 'Pet Store', 'Taiwanese Restaurant', 'Gift Shop',
#        'Market', 'Theme Restaurant', 'Salon / Barbershop', 'Juice Bar',
#        'Ethiopian Restaurant', "Men's Store", 'Martial Arts Dojo',
#        'Gay Bar'], dtype=object)

# %%
# one hot encoding
TorontoDT_onehot = pd.get_dummies(TorontoDT_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
TorontoDT_onehot['Neighborhood'] = TorontoDT_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [TorontoDT_onehot.columns[-1]] + list(TorontoDT_onehot.columns[:-1])
TorontoDT_onehot = TorontoDT_onehot[fixed_columns]

# TorontoDT_onehot.head();
TorontoDT_grouped = TorontoDT_onehot.groupby('Neighborhood').mean().reset_index()
TorontoDT_grouped
TorontoDT_grouped.shape
# Out:
#                                          Neighborhood  Yoga Studio  Airport  \
# 0                                         Berczy Park         0.00   0.0000
# 1   CN Tower, King and Spadina, Railway Lands, Har...         0.00   0.0625
# 2                                  Central Bay Street         0.00   0.0000
# 3                                            Christie         0.00   0.0000
# 4                                Church and Wellesley         0.00   0.0000
# 5                      Commerce Court, Victoria Hotel         0.00   0.0000
# 6              First Canadian Place, Underground city         0.00   0.0000
# 7                            Garden District, Ryerson         0.00   0.0000
# 8   Harbourfront East, Union Station, Toronto Islands         0.00   0.0000
# 9           Kensington Market, Chinatown, Grange Park         0.00   0.0000
# 10        Queen's Park, Ontario Provincial Government         0.04   0.0000
# 11                          Regent Park, Harbourfront         0.00   0.0000
# 12                           Richmond, Adelaide, King         0.00   0.0000
# 13                                           Rosedale         0.00   0.0000
# 14                                     St. James Town         0.00   0.0000
# 15                        St. James Town, Cabbagetown         0.00   0.0000
# 16                                     Stn A PO Boxes         0.00   0.0000
# 17           Toronto Dominion Centre, Design Exchange         0.00   0.0000
# 18                     University of Toronto, Harbord         0.04   0.0000
#
#     Airport Food Court  Airport Gate  Airport Lounge  Airport Service  \
# 0               0.0000        0.0000           0.000           0.0000
# 1               0.
#     Tailor Shop  Taiwanese Restaurant  Thai Restaurant  Theater  \
# 0          0.04                  0.00             0.04     0.00
# 1          0.00                  0.00             0.00     0.00
# 2          0.00                  0.00             0.00     0.00
# 3          0.00                  0.00             0.00     0.00
# 4          0.00                  0.00             0.04     0.00
# 5          0.00                  0.00             0.00     0.00
# 6          0.00                  0.00             0.00     0.00
# 7          0.00                  0.00             0.04     0.04
# 8          0.00                  0.00             0.00     0.00
# 9          0.00                  0.00             0.00     0.00
# 10         0.00                  0.00             0.00     0.04
# 11         0.00                  0.00             0.00     0.00
# 12         0.00                  0.00             0.00     0.00
# 13         0.00                  0.00             0.00     0.00
# 14         0.00                  0.00             0.00     0.04
# 15         0.00                  0.04             0.04     0.00
# 16         0.04                  0.00             0.04     0.00
# 17         0.00                  0.00             0.00     0.00
# 18         0.00                  0.00             0.00     0.04
#
#     Theme Restaurant  Trail  Train Station  Vegetarian / Vegan Restaurant  \
# 0               0.00   0.00           0.00                           0.04
# 1               0.00   0.00           0.00                           0.00
# 2               0.00   0.00           0.00                           0.04
# 3               0.00   0.00           0.00                           0.00
# 4               0.04   0.00           0.00                           0.00
# 5               0.00   0.00           0.00                           0.00
# 6               0.00   0.00           0.00                           0.00
# 7               0.00   0.00           0.00                           0.00
# 8               0.00   0.00           0.00                           0.00
# 9               0.00   0.00           0.00                           0.04
# 10              0.00   0.00           0.00                           0.00
# 11              0.00   0.00           0.00                           0.00
# 12              0.00   0.00           0.00                           0.04
# 13              0.00   0.25           0.00                           0.00
# 14              0.00   0.00           0.00                           0.04
# 15              0.00   0.00           0.00                           0.00
# 16              0.00   0.00           0.00                           0.04
# 17              0.00   0.00           0.04                           0.00
# 18              0.00   0.00           0.00                           0.00
#
#     Video Game Store  Vietnamese Restaurant  Wine Bar
# 0               0.00                   0.00      0.00
# 1               0.00                   0.00      0.00
# 2               0.00                   0.00      0.00
# 3               0.00                   0.00      0.00
# 4               0.00                   0.00      0.00
# 5               0.00                   0.00      0.00
# 6               0.00                   0.00      0.00
# 7               0.00                   0.00      0.00
# 8               0.00                   0.00      0.00
# 9               0.00                   0.08      0.04
# 10              0.00                   0.00      0.00
# 11              0.00                   0.00      0.00
# 12              0.00                   0.00      0.00
# 13              0.00                   0.00      0.00
# 14              0.00                   0.00      0.00
# 15              0.00                   0.00      0.00
# 16              0.00                   0.00      0.00
# 17              0.00                   0.00      0.00
# 18              0.04                   0.00      0.00
# (19, 140)

# %%
num_top_venues = 5

# for hood in TorontoDT_grouped['Neighborhood']:
#     print("----"+hood+"----");
#     temp = TorontoDT_grouped[TorontoDT_grouped['Neighborhood'] == hood].T.reset_index()
#     temp.columns = ['venue','freq']
#     temp = temp.iloc[1:]
#     temp['freq'] = temp['freq'].astype(float)
#     temp = temp.round({'freq': 2})
#     print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
#     print('\n')

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]


num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = TorontoDT_grouped['Neighborhood']

for ind in np.arange(TorontoDT_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(TorontoDT_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(25)
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                                         Berczy Park    Seafood Restaurant
# 1   CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 2                                  Central Bay Street           Coffee Shop
# 3                                            Christie         Grocery Store
# 4                                Church and Wellesley                  Park
# 5                      Commerce Court, Victoria Hotel                  Café
# 6              First Canadian Place, Underground city                  Café
# 7                            Garden District, Ryerson                  Café
# 8   Harbourfront East, Union Station, Toronto Islands                  Park
# 9           Kensington Market, Chinatown, Grange Park                  Café
# 10        Queen's Park, Ontario Provincial Government           Coffee Shop
# 11                          Regent Park, Harbourfront           Coffee Shop
# 12                           Richmond, Adelaide, King           Coffee Shop
# 13                                           Rosedale                  Park
# 14                                     St. James Town           Coffee Shop
# 15                        St. James Town, Cabbagetown    Italian Restaurant
# 16                                     Stn A PO Boxes    Seafood Restaurant
# 17           Toronto Dominion Centre, Design Exchange           Coffee Shop
# 18                     University of Toronto, Harbord                  Café
#
#    2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 0         Farmers Market             Restaurant                Bistro
# 1         Airport Lounge            Coffee Shop       Harbor / Marina
# 2     Italian Restaurant                   Café                   Spa
# 3                   Café                   Park    Italian Restaurant
# 4         Ice Cream Shop    Japanese Restaurant    Salon / Barbershop
# 5    Japanese Restaurant             Restaurant           Coffee Shop
# 6            Coffee Shop             Restaurant             Speakeasy
# 7         Clothing Store            Coffee Shop         Burrito Place
# 8                   Café                  Plaza                 Hotel
# 9     Mexican Restaurant  Vietnamese Restaurant          Cocktail Bar
# 10                 Diner            Yoga Studio         Smoothie Shop
# 11        Breakfast Spot                   Park                Bakery
# 12                 Hotel             Steakhouse      Sushi Restaurant
# 13            Playground                  Trail    College Rec Center
# 14             Gastropub                   Café            Restaurant
# 15                  Café             Restaurant                 Diner
# 16        Farmers Market           Cocktail Bar                  Café
# 17                  Café    Japanese Restaurant            Steakhouse
# 18                Bakery    Japanese Restaurant             Bookstore
#
#          5th Most Common Venue      6th Most Common Venue  \
# 0                    Jazz Club                   Beer Bar
# 1                     Boutique           Sculpture Garden
# 2   Modern European Restaurant         Miscellaneous Shop
# 3                    Nightclub                Coffee Shop
# 4                    Juice Bar                 Restaurant
# 5                    Gastropub              Deli / Bodega
# 6                    Gastropub     Gluten-free Restaurant
# 7            Electronics Store               Burger Joint
# 8      New American Restaurant      Performing Arts Venue
# 9                 Gourmet Shop                Gaming Cafe
# 10                        Park                       Café
# 11              Farmers Market        Distribution Center
# 12        Gym / Fitness Center         Seafood Restaurant
# 13                Dance Studio                   Creperie
# 14                       Hotel  Middle Eastern Restaurant
# 15        Caribbean Restaurant                  Gastropub
# 16                  Restaurant                       Park
# 17               Deli / Bodega             Sandwich Place
# 18                  Restaurant          French Restaurant
#
#         7th Most Common Venue 8th Most Common Venue    9th Most Common Venue  \
# 0          Basketball Stadium   Japanese Restaurant                   Museum
# 1         Rental Car Location                 Plane            Boat or Ferry
# 2   Middle Eastern Restaurant                  Park                Gastropub
# 3                 Candy Store            Restaurant               Baby Store
# 4                   Bookstore      Ramen Restaurant                      Pub
# 5                    Beer Bar                   Gym     Gym / Fitness Center
# 6                         Gym  Gym / Fitness Center            Deli / Bodega
# 7                 Pizza Place                 Plaza       College Rec Center
# 8             Bubble Tea Shop                  Lake                Roof Deck
# 9                 Fish Market        Farmers Market             Dessert Shop
# 10              Burrito Place    Mexican Restaurant                 Creperie
# 11                        Pub    Mexican Restaurant             Dessert Shop
# 12                Pizza Place            Smoke Shop         Asian Restaurant
# 13             Cosmetics Shop          Concert Hall               Comic Shop
# 14                 Poke Place        Cosmetics Shop                 Creperie
# 15                  Pet Store               Butcher                   Market
# 16               Concert Hall              Beer Bar                Jazz Club
# 17                   Beer Bar                Museum                      Pub
# 18         Italian Restaurant          Dessert Shop  Comfort Food Restaurant
#
#      10th Most Common Venue
# 0              Liquor Store
# 1          Airport Terminal
# 2           Bubble Tea Shop
# 3        Athletics & Sports
# 4            Breakfast Spot
# 5       American Restaurant
# 6               Pizza Place
# 7                 Bookstore
# 8               Salad Place
# 9               Coffee Shop
# 10                 Beer Bar
# 11           Chocolate Shop
# 12                Speakeasy
# 13  Comfort Food Restaurant
# 14                    Diner
# 15                      Pub
# 16      Japanese Restaurant
# 17                   Bakery
# 18              College Gym

# %%
# set number of clusters
kclusters = 5

TorontoDT_grouped_clustering = TorontoDT_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(TorontoDT_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

TorontoDT_merged = torontoDT_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
TorontoDT_merged = TorontoDT_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

TorontoDT_merged.head() # check the last columns!

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(TorontoDT_merged['Latitude'], TorontoDT_merged['Longitude'], TorontoDT_merged['Neighborhood'], TorontoDT_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# array([1, 4, 0, 3, 1, 3, 3, 3, 1, 1], dtype=int32)
#   PostalCode           Borough                                 Neighborhood  \
# 0        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2        M5B  Downtown Toronto                     Garden District, Ryerson
# 3        M5C  Downtown Toronto                               St. James Town
# 4        M5E  Downtown Toronto                                  Berczy Park
#
#   Latitude Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.6543  -79.3606               0           Coffee Shop
# 1  43.6623  -79.3895               0           Coffee Shop
# 2  43.6572  -79.3789               3                  Café
# 3  43.6515  -79.3754               3           Coffee Shop
# 4  43.6448  -79.3733               1    Seafood Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Breakfast Spot                  Park                Bakery
# 1                 Diner           Yoga Studio         Smoothie Shop
# 2        Clothing Store           Coffee Shop         Burrito Place
# 3             Gastropub                  Café            Restaurant
# 4        Farmers Market            Restaurant                Bistro
#
#   5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 0        Farmers Market        Distribution Center                   Pub
# 1                  Park                       Café         Burrito Place
# 2     Electronics Store               Burger Joint           Pizza Place
# 3                 Hotel  Middle Eastern Restaurant            Poke Place
# 4             Jazz Club                   Beer Bar    Basketball Stadium
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Mexican Restaurant          Dessert Shop         Chocolate Shop
# 1    Mexican Restaurant              Creperie               Beer Bar
# 2                 Plaza    College Rec Center              Bookstore
# 3        Cosmetics Shop              Creperie                  Diner
# 4   Japanese Restaurant                Museum           Liquor Store
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
TorontoDT_merged.loc[TorontoDT_merged['Cluster Labels'] == 0, TorontoDT_merged.columns[[2] + list(range(5, TorontoDT_merged.shape[1]))]]
# Out:
#                                   Neighborhood  Cluster Labels  \
# 0                    Regent Park, Harbourfront               0
# 1  Queen's Park, Ontario Provincial Government               0
# 5                           Central Bay Street               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop        Breakfast Spot                  Park
# 1           Coffee Shop                 Diner           Yoga Studio
# 5           Coffee Shop    Italian Restaurant                  Café
#
#   4th Most Common Venue       5th Most Common Venue 6th Most Common Venue  \
# 0                Bakery              Farmers Market   Distribution Center
# 1         Smoothie Shop                        Park                  Café
# 5                   Spa  Modern European Restaurant    Miscellaneous Shop
#
#        7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                        Pub    Mexican Restaurant          Dessert Shop
# 1              Burrito Place    Mexican Restaurant              Creperie
# 5  Middle Eastern Restaurant                  Park             Gastropub
#
#   10th Most Common Venue
# 0         Chocolate Shop
# 1               Beer Bar
# 5        Bubble Tea Shop

# %%
TorontoDT_merged.loc[TorontoDT_merged['Cluster Labels'] == 1, TorontoDT_merged.columns[[2] + list(range(5, TorontoDT_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 4                                         Berczy Park               1
# 8   Harbourfront East, Union Station, Toronto Islands               1
# 11                     University of Toronto, Harbord               1
# 12          Kensington Market, Chinatown, Grange Park               1
# 15                                     Stn A PO Boxes               1
# 18                               Church and Wellesley               1
#
#    1st Most Common Venue 2nd Most Common Venue  3rd Most Common Venue  \
# 4     Seafood Restaurant        Farmers Market             Restaurant
# 8                   Park                  Café                  Plaza
# 11                  Café                Bakery    Japanese Restaurant
# 12                  Café    Mexican Restaurant  Vietnamese Restaurant
# 15    Seafood Restaurant        Farmers Market           Cocktail Bar
# 18                  Park        Ice Cream Shop    Japanese Restaurant
#
#    4th Most Common Venue    5th Most Common Venue  6th Most Common Venue  \
# 4                 Bistro                Jazz Club               Beer Bar
# 8                  Hotel  New American Restaurant  Performing Arts Venue
# 11             Bookstore               Restaurant      French Restaurant
# 12          Cocktail Bar             Gourmet Shop            Gaming Cafe
# 15                  Café               Restaurant                   Park
# 18    Salon / Barbershop                Juice Bar             Restaurant
#
#    7th Most Common Venue 8th Most Common Venue    9th Most Common Venue  \
# 4     Basketball Stadium   Japanese Restaurant                   Museum
# 8        Bubble Tea Shop                  Lake                Roof Deck
# 11    Italian Restaurant          Dessert Shop  Comfort Food Restaurant
# 12           Fish Market        Farmers Market             Dessert Shop
# 15          Concert Hall              Beer Bar                Jazz Club
# 18             Bookstore      Ramen Restaurant                      Pub
#
#    10th Most Common Venue
# 4            Liquor Store
# 8             Salad Place
# 11            College Gym
# 12            Coffee Shop
# 15    Japanese Restaurant
# 18         Breakfast Spot

# %%
TorontoDT_merged.loc[TorontoDT_merged['Cluster Labels'] == 2, TorontoDT_merged.columns[[2] + list(range(5, TorontoDT_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 14     Rosedale               2                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14                 Trail    College Rec Center          Dance Studio
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 14              Creperie        Cosmetics Shop          Concert Hall
#
#    9th Most Common Venue   10th Most Common Venue
# 14            Comic Shop  Comfort Food Restaurant

# %%
TorontoDT_merged.loc[TorontoDT_merged['Cluster Labels'] == 3, TorontoDT_merged.columns[[2] + list(range(5, TorontoDT_merged.shape[1]))]]
# Out:
#                                 Neighborhood  Cluster Labels  \
# 2                   Garden District, Ryerson               3
# 3                             St. James Town               3
# 6                                   Christie               3
# 7                   Richmond, Adelaide, King               3
# 9   Toronto Dominion Centre, Design Exchange               3
# 10            Commerce Court, Victoria Hotel               3
# 16               St. James Town, Cabbagetown               3
# 17    First Canadian Place, Underground city               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 2                   Café        Clothing Store           Coffee Shop
# 3            Coffee Shop             Gastropub                  Café
# 6          Grocery Store                  Café                  Park
# 7            Coffee Shop                 Hotel            Steakhouse
# 9            Coffee Shop                  Café   Japanese Restaurant
# 10                  Café   Japanese Restaurant            Restaurant
# 16    Italian Restaurant                  Café            Restaurant
# 17                  Café           Coffee Shop            Restaurant
#
#    4th Most Common Venue 5th Most Common Venue      6th Most Common Venue  \
# 2          Burrito Place     Electronics Store               Burger Joint
# 3             Restaurant                 Hotel  Middle Eastern Restaurant
# 6     Italian Restaurant             Nightclub                Coffee Shop
# 7       Sushi Restaurant  Gym / Fitness Center         Seafood Restaurant
# 9             Steakhouse         Deli / Bodega             Sandwich Place
# 10           Coffee Shop             Gastropub              Deli / Bodega
# 16                 Diner  Caribbean Restaurant                  Gastropub
# 17             Speakeasy             Gastropub     Gluten-free Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 2            Pizza Place                 Plaza    College Rec Center
# 3             Poke Place        Cosmetics Shop              Creperie
# 6            Candy Store            Restaurant            Baby Store
# 7            Pizza Place            Smoke Shop      Asian Restaurant
# 9               Beer Bar                Museum                   Pub
# 10              Beer Bar                   Gym  Gym / Fitness Center
# 16             Pet Store               Butcher                Market
# 17                   Gym  Gym / Fitness Center         Deli / Bodega
#
#    10th Most Common Venue
# 2               Bookstore
# 3                   Diner
# 6      Athletics & Sports
# 7               Speakeasy
# 9                  Bakery
# 10    American Restaurant
# 16                    Pub
# 17            Pizza Place

# %%
TorontoDT_merged.loc[TorontoDT_merged['Cluster Labels'] == 4, TorontoDT_merged.columns[[2] + list(range(5, TorontoDT_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 13  CN Tower, King and Spadina, Railway Lands, Har...               4
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 13       Airport Service        Airport Lounge           Coffee Shop
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 13       Harbor / Marina              Boutique      Sculpture Garden
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 13   Rental Car Location                 Plane         Boat or Ferry
#
#    10th Most Common Venue
# 13       Airport Terminal
